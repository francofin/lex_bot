# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path
import hvplot.pandas

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
url_data = pd.DataFrame(json.loads(requests.get(url).content)['Data']).T

# %%
url_data
# Out:
#                Id                        Url  \
# 42           4321         /coins/42/overview
# 300        749869        /coins/300/overview
# 365         33639        /coins/365/overview
# 404         21227        /coins/404/overview
# 433        926547        /coins/433/overview
# ...           ...                        ...
# AQUA       944519       /coins/aqua/overview
# NEETCOIN   933733   /coins/neetcoin/overview
# NEET       944521       /coins/neet/overview
# CHESSCOIN   22407  /coins/chesscoin/overview
# CHESS      944523      /coins/chess/overview
#
#                                    ImageUrl ContentCreatedOn       Name  \
# 42                   /media/35650717/42.jpg       1427211129         42
# 300                 /media/27010595/300.png       1517935016        300
# 365                   /media/352070/365.png       1480032918        365
# 404         /media/35650851/404-300x300.jpg       1466100361        404
# ...

# %%
# Alternatively, use the provided csv file:
file_path = Path("crypto_data.csv")

# Create a DataFrame
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
cleaned_df = data[['CoinName', 'Algorithm', 'IsTrading', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']]

# %%
# Keep only cryptocurrencies that are trading
is_trading_data = cleaned_df[cleaned_df['IsTrading']==True]

# %%
is_trading_data
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
is_trading_data['Algorithm'].unique()
# Out:
# array(['Scrypt', 'X11', 'SHA-256', 'X13', 'Ethash', 'CryptoNight-V7',
#        'Equihash', 'SHA-512', 'Multiple', 'X15', 'NIST5', 'Quark',
#        'Groestl', 'PoS', 'NeoScrypt', 'SHA3', 'HybridScryptHash256',
#        'Scrypt-n', 'PHI1612', 'Lyra2REv2', 'CryptoNight', 'Shabal256',
#        'Counterparty', 'Blake', 'Momentum', 'Stanford Folding', 'QuBit',
#        'XG Hash', 'M7 POW', 'Curve25519', 'Lyra2RE', 'QUAIT', 'vDPOS',
#        'Blake2b', 'BLAKE256', '1GB AES Pattern Search', 'Dagger',
#        'CryptoNight-Lite', 'X11GOST', 'SHA-256D', 'POS 3.0',
#        'Progressive-n', 'DPoS', 'Lyra2Z', 'X14', 'Time Travel', 'Argon2',
#        'Keccak', 'Blake2S', 'Dagger-Hashimoto', '536', 'Argon2d',
#        'Cloverhash', 'Skein', 'SkunkHash v2 Raptor',
#        'VeChainThor Authority', 'Ouroboros', 'POS 2.0', 'SkunkHash',
#        'C11', 'Proof-of-BibleHash', 'SHA-256 + Hive',
#        'Proof-of-Authority', 'XEVAN', 'VBFT', 'YescryptR16', 'IMesh',
# ...

# %%
# Keep only cryptocurrencies with a working algorithm
working_algo_data = is_trading_data[is_trading_data['Algorithm']!=" "]

# %%
working_algo_data
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
# Remove the "IsTrading" column
working_algo_feat = working_algo_data.drop('IsTrading', axis=1)

# %%
# Remove rows with at least 1 null value
working_algo_feat.dropna(inplace=True)

# %%
working_algo_feat
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined
cryptos_mined = working_algo_feat[working_algo_feat['TotalCoinsMined'] != 0]

# %%
# Drop rows where there are 'N/A' text values
cryptos_mined[cryptos_mined['CoinName']=="N/A"]
# Out:
# Empty DataFrame
# Columns: [CoinName, Algorithm, ProofType, TotalCoinsMined, TotalCoinSupply]
# Index: []

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coin_names = cryptos_mined['CoinName'].to_frame()

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
cryptos_mined.drop('CoinName', axis=1, inplace=True)
# Out:
# C:\Users\franc\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cryptos_mined
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 4 columns]

# %%
# Create dummy variables for text features
cryptos_binary_encoded = pd.get_dummies(cryptos_mined, columns=["Algorithm", "ProofType"])
cryptos_binary_encoded.head()
# Out:
#    TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0     4.199995e+01              42                                 0
# 2     1.055185e+09       532000000                                 0
# 5     2.927942e+10    314159265359                                 0
# 7     1.792718e+07        21000000                                 0
# 8     1.076842e+08               0                                 0
#
#    Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0              0                  0                   0                0
# 2              0                  0                   0                0
# 5              0                  0                   0                0
# 7              0                  0                   0                0
# 8              0                  0                   0                0
#
#    Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# ...

# %%
cryptos_binary_encoded.drop(['Algorithm_1GB AES Pattern Search', 'ProofType_Proof of Trust'], axis=1, inplace=True)

# %%
# Standardize data
data_scaler = StandardScaler()

# %%
data_scaler.fit(cryptos_binary_encoded)
# Out:
# StandardScaler()

# %%
crypto_data_scaled = data_scaler.transform(cryptos_binary_encoded)

# %%
crypto_data_scaled[1]
# Out:
# array([-0.09358885, -0.14499604, -0.0433555 , -0.0433555 , -0.06137164,
#        -0.07523548, -0.0433555 , -0.06137164, -0.06137164, -0.0433555 ,
#        -0.0433555 , -0.19226279, -0.06137164, -0.09731237, -0.0433555 ,
#        -0.11536024, -0.07523548, -0.0433555 , -0.0433555 , -0.15176505,
#        -0.0433555 , -0.13105561, -0.0433555 , -0.0433555 , -0.08695652,
#        -0.0433555 , -0.0433555 , -0.0433555 , -0.0433555 , -0.06137164,
#        -0.0433555 , -0.08695652, -0.08695652, -0.08695652, -0.0433555 ,
#        -0.13105561, -0.13827675, -0.13827675, -0.0433555 , -0.06137164,
#        -0.0433555 , -0.07523548, -0.1815096 , -0.0433555 , -0.0433555 ,
#        -0.0433555 , -0.07523548, -0.15811388, -0.3145935 , -0.0433555 ,
#        -0.08695652, -0.07523548, -0.06137164, -0.0433555 ,  1.38873015,
#        -0.0433555 , -0.0433555 , -0.06137164, -0.0433555 , -0.0433555 ,
#        -0.0433555 , -0.0433555 , -0.0433555 , -0.0433555 , -0.0433555 ,
# ...

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
crypto_pca = pca.fit_transform(crypto_data_scaled)

# %%
df_crypto_pca = pd.DataFrame(
    data=crypto_pca, columns=["principal component 1", "principal component 2", "principal component 3"]
)
df_crypto_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3
# 0              -0.312519               1.082506              -0.420016
# 1              -0.295814               1.082637              -0.420175
# 2               2.326063               1.702852              -0.567104
# 3              -0.147322              -1.315726               0.160548
# 4              -0.161060              -2.055832               0.313591

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_crypto_pca)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# C:\Users\franc\anaconda3\envs\tf\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   f"KMeans is known to have a memory leak on Windows "
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(df_crypto_pca)

# Predict clusters
predictions = model.predict(df_crypto_pca)

# Add the predicted class columns
df_crypto_pca["class"] = model.labels_
df_crypto_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  class
# 0              -0.312519               1.082506              -0.420016      0
# 1              -0.295814               1.082637              -0.420175      0
# 2               2.326063               1.702852              -0.567104      0
# 3              -0.147322              -1.315726               0.160548      2
# 4              -0.161060              -2.055832               0.313591      2

# %%
df_crypto_pca
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                -0.312519               1.082506              -0.420016
# 1                -0.295814               1.082637              -0.420175
# 2                 2.326063               1.702852              -0.567104
# 3                -0.147322              -1.315726               0.160548
# 4                -0.161060              -2.055832               0.313591
# ..                     ...                    ...                    ...
# 528               2.458981               0.839028               0.095407
# 529              -0.310560               1.082389              -0.420028
# 530               0.320553              -2.309771               0.313090
# 531              -0.143245              -2.104742               0.391365
# 532              -0.298150               0.764220              -0.257591
#
#      class
# 0        0
# 1        0
# 2        0
# 3        2
# 4        2
# ..     ...
# ...

# %%
clustered_df = pd.concat([cryptos_mined.reset_index(), df_crypto_pca, coin_names.reset_index()], axis=1)

# %%
crypto_df = clustered_df.loc[:,~clustered_df.columns.duplicated()].set_index("CoinName")

# %%
crypto_df.drop("index", axis=1, inplace=True)

# %%
crypto_df
# Out:
#                Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# CoinName
# 42 Coin           Scrypt   PoW/PoS     4.199995e+01              42
# 404Coin           Scrypt   PoW/PoS     1.055185e+09       532000000
# EliteCoin            X13   PoW/PoS     2.927942e+10    314159265359
# Bitcoin          SHA-256       PoW     1.792718e+07        21000000
# Ethereum          Ethash       PoW     1.076842e+08               0
# ...                  ...       ...              ...             ...
# ZEPHYR           SHA-256      DPoS     2.000000e+09      2000000000
# Gapcoin           Scrypt   PoW/PoS     1.493105e+07       250000000
# Beldex       CryptoNight       PoW     9.802226e+08      1400222610
# Horizen         Equihash       PoW     7.296538e+06        21000000
# BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
#              principal component 1  principal component 2  \
# CoinName
# 42 Coin                  -0.312519               1.082506
# ...

# %%
crypto_df['totalCoinsMinedScaled'] = crypto_df['TotalCoinsMined'].apply(lambda x: (x - crypto_df['TotalCoinsMined'].mean())/crypto_df['TotalCoinsMined'].std())
# crypto_df['totalCoinsSupplyScaled'] = crypto_data_scaled[1]

# %%
crypto_df.TotalCoinSupply
# Out:
# CoinName
# 42 Coin                  42
# 404Coin           532000000
# EliteCoin      314159265359
# Bitcoin            21000000
# Ethereum                  0
#                    ...
# ZEPHYR           2000000000
# Gapcoin           250000000
# Beldex           1400222610
# Horizen            21000000
# BitcoinPlus         1000000
# Name: TotalCoinSupply, Length: 533, dtype: object

# %%
crypto_df['CoinsAsInt'] = crypto_df.TotalCoinSupply.apply(lambda x: float(x))

# %%
crypto_df['totalCoinsSupplyScaled'] = crypto_df['CoinsAsInt'].apply(lambda x: (x - crypto_df['CoinsAsInt'].mean())/crypto_df['CoinsAsInt'].std())

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
crypto_df.hvplot.scatter(
    x="totalCoinsMinedScaled",
    y="totalCoinsSupplyScaled",
    hover_cols=["CoinName"], 
    by='class'
)
# Out:
# :NdOverlay   [class]
#    :Scatter   [totalCoinsMinedScaled]   (totalCoinsSupplyScaled,CoinName)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

# %%
# Print the total number of tradable cryptocurrencies
